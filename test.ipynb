# %%
file_paths = [
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_1.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_2.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_3.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_4.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_5.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_6.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_7.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_8.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_9.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_10.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_11.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_12.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_13.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_14.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_15.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_16.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_17.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_18.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_19.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_20.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_21.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_22.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_23.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_24.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_25.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_26.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_27.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_28.png",
    "/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_29.png"
  ]

# %%
print(file_paths)
# Out:
# ['/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_1.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_2.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_3.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_4.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_5.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_6.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_7.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_8.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025
# ...

# %%
for item in file_paths:
    print(item)
# Out:
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_1.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_2.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_3.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_4.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_5.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_6.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_7.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_8.png
# ...

# %%
file_paths.sort()

# %%
print(file_paths)
# Out:
# ['/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_1.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_10.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_11.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_12.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_13.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_14.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_15.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_16.png', '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗
# ...

# %%
for item in file_paths:
    print(item)
# Out:
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_1.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_10.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_11.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_12.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_13.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_14.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_15.png
# /Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/经皮冠状动脉介入治疗指南（2025）/经皮冠状动脉介入治疗指南（2025）_16.png
# ...
