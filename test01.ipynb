png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_13.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":13},{"task_id":"93f4bea3-d168-42fe-9775-1e96e8c10e0d","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_14.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_14.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":14},{"task_id":"36bdc075-8184-4aa3-a97b-a38513e9cd43","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_15.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_15.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":15},{"task_id":"2c7c06f3-00fe-464d-a102-8674473d5465","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_16.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_16.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":16},{"task_id":"bfe6ff42-ca3e-4170-bfd5-65548945ed5d","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_17.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_17.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":17},{"task_id":"957087a2-9d0f-413e-a9fc-19ffba934f0c","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_18.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_18.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":18},{"task_id":"65c62307-afa1-4e59-a501-5c3915f39aab","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_19.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_19.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":19},{"task_id":"395a4843-7669-443c-99df-05c74b8f750c","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_20.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_20.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":20},{"task_id":"2bbea015-c397-48cd-aef0-9f24c959339f","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_21.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_21.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":21},{"task_id":"3b3d37e7-0dfb-4fd0-8657-b0b3dca77ed9","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_22.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_22.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":22},{"task_id":"abf9c7ca-7a65-48ba-9d85-87bb2008b0ef","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_23.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_23.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":23},{"task_id":"282dc6db-e18f-4ca0-b4cb-d747f7e0e32d","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_24.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_24.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":24},{"task_id":"0928beb3-f1af-481b-8c0f-e147178757ae","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_25.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_25.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":25},{"task_id":"2ec0f347-cd41-42bc-9b65-f60cc8e523b6","image_filename":"中国慢性冠脉综合征患者诊断及管理指南_26.png","image_path":"/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_26.png","output_file":"","status":"pending","success":"","error":"","elapsed_time":"","strategy":"","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南","page_num":26}]}

# %%
result.keys()
# Out:
# dict_keys(['success', 'message', 'pdf_name', 'total_tasks', 'task_ids', 'tasks'])

# %%
result["task_ids"]
# Out:
# ['12517472-8484-4ed2-b3f1-b729dd0483e5',
#  'edfad951-22d7-4692-bedc-f5aa16601b8e',
#  '7276d763-4f76-4196-8c56-e727b9cfc194',
#  '96c4ef11-317c-4524-be32-406f5ff4894c',
#  '3ccd1641-d16f-4f3f-b600-f4b1c6f82690',
#  '1ff8daaa-d39e-493e-a90e-f810d6f5b65c',
#  'cb73eefc-bd1e-412d-bd7c-3a3b8d9d0fe4',
#  '7be18e9c-6edf-438b-a645-93594f9c6286',
#  '890a472e-0569-4ed9-b0a9-4fcb2aec193b',
#  '9260b68e-4855-438d-a85f-a89a596a50e2',
#  'c1f60a00-7b62-4076-9321-398040c80987',
#  'c97e2849-bb17-4f78-9ee8-edd2ce5a7dae',
#  '89508d21-ef64-4d8d-8bad-c08d40b0b5c9',
#  '93f4bea3-d168-42fe-9775-1e96e8c10e0d',
#  '36bdc075-8184-4aa3-a97b-a38513e9cd43',
#  '2c7c06f3-00fe-464d-a102-8674473d5465',
#  'bfe6ff42-ca3e-4170-bfd5-65548945ed5d',
#  '957087a2-9d0f-413e-a9fc-19ffba934f0c',
#  '65c62307-afa1-4e59-a501-5c3915f39aab',
#  '395a4843-7669-443c-99df-05c74b8f750c',
#  '2bbea015-c397-48cd-aef0-9f24c959339f',
#  '3b3d37e7-0dfb-4fd0-8657-b0b3dca77ed9',
#  'abf9c7ca-7a65-48ba-9d85-87bb2008b0ef',
# ...

# %%
result["tasks"]
# Out:
# [{'task_id': '12517472-8484-4ed2-b3f1-b729dd0483e5',
#   'image_filename': '中国慢性冠脉综合征患者诊断及管理指南_1.png',
#   'image_path': '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_1.png',
#   'output_file': '',
#   'status': 'pending',
#   'success': '',
#   'error': '',
#   'elapsed_time': '',
#   'strategy': '',
#   'pdf_name': '中国慢性冠脉综合征患者诊断及管理指南',
#   'page_num': 1},
#  {'task_id': 'edfad951-22d7-4692-bedc-f5aa16601b8e',
#   'image_filename': '中国慢性冠脉综合征患者诊断及管理指南_2.png',
#   'image_path': '/Users/rossw/Downloads/projects/clinical-laboratory/guidelines_RAG/中国慢性冠脉综合征患者诊断及管理指南/中国慢性冠脉综合征患者诊断及管理指南_2.png',
#   'output_file': '',
#   'status': 'pending',
#   'success': '',
#   'error': '',
#   'elapsed_time': '',
#   'strategy': '',
#   'pdf_name': '中国慢性冠脉综合征患者诊断及管理指南',
#   'page_num': 2},
#  {'task_id': '7276d763-4f76-4196-8c56-e727b9cfc194',
#   'image_filename': '中国慢性冠脉综合征患者诊断及管理指南_3.png',
# ...

# %%
vlm_result = "{"success":true,"message":"已提交 26 个提取任务，正在后台执行","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南.pdf","total_tasks":26,"task_ids":["4f656668-b0b9-43b0-b989-022c2778689f","24b151c7-e51f-40e0-8c6c-47b3670b0876","63a18862-84a1-437c-9d12-a6f8a6f7fb6a","6cf8226e-1e1d-4746-b4d5-f83efed90e6e","d77e378d-de1e-46e5-abc3-140e0c479f40","0efada57-0fb5-43d9-8465-84f2f99ceda4","b7ddb1b9-9268-4eeb-b23d-7bd4fd68d8c2","a520c88d-47e7-4cfa-8600-21b8dfe3afd8","77ebdae9-b40e-40d1-b720-306a03b82740","b2f04ace-bbd3-4ca7-bea0-13585e84842c","4d4f95ac-92a6-4e5f-b384-456fb21b8fc4","edfef8ab-fcc2-4999-9b93-a4ba2a07afb5","12435f76-7106-4691-b78d-4c04e8e46998","f1c9c707-14de-4288-b300-4b17f473e49d","522ecbcd-1b21-4214-a9d2-b2185a18dc23","6d6e14f3-3f8c-4fc9-9757-29e03958253f","5127a5ec-5a3d-4c89-8b62-31db1ee6b9a1","2f800e92-7396-4dfc-8d2e-23a537b09744","8fdbe65d-8bff-48de-a57e-46cff86dd1b9","863eccea-7e8a-43d9-bb38-8cc218e8bc8d","37ee66a0-e0bb-4375-8057-0a3175017ca5","b177693f-e3c9-462c-ab42-8fe9ebd38513","4ad8fe53-0443-4f16-85f8-0973491d907a","fa3b9394-705d-4912-86e9-a28a85d1806d","6005de4d-5464-4339-bbaf-99fe6edc4701","1ced7933-6529-48d2-a950-b3f585830191"]}"
# Out:
#   Cell In[10], line 1
# ...

# %%
vlm_result = '''{"success":true,"message":"已提交 26 个提取任务，正在后台执行","pdf_name":"中国慢性冠脉综合征患者诊断及管理指南.pdf","total_tasks":26,"task_ids":["4f656668-b0b9-43b0-b989-022c2778689f","24b151c7-e51f-40e0-8c6c-47b3670b0876","63a18862-84a1-437c-9d12-a6f8a6f7fb6a","6cf8226e-1e1d-4746-b4d5-f83efed90e6e","d77e378d-de1e-46e5-abc3-140e0c479f40","0efada57-0fb5-43d9-8465-84f2f99ceda4","b7ddb1b9-9268-4eeb-b23d-7bd4fd68d8c2","a520c88d-47e7-4cfa-8600-21b8dfe3afd8","77ebdae9-b40e-40d1-b720-306a03b82740","b2f04ace-bbd3-4ca7-bea0-13585e84842c","4d4f95ac-92a6-4e5f-b384-456fb21b8fc4","edfef8ab-fcc2-4999-9b93-a4ba2a07afb5","12435f76-7106-4691-b78d-4c04e8e46998","f1c9c707-14de-4288-b300-4b17f473e49d","522ecbcd-1b21-4214-a9d2-b2185a18dc23","6d6e14f3-3f8c-4fc9-9757-29e03958253f","5127a5ec-5a3d-4c89-8b62-31db1ee6b9a1","2f800e92-7396-4dfc-8d2e-23a537b09744","8fdbe65d-8bff-48de-a57e-46cff86dd1b9","863eccea-7e8a-43d9-bb38-8cc218e8bc8d","37ee66a0-e0bb-4375-8057-0a3175017ca5","b177693f-e3c9-462c-ab42-8fe9ebd38513","4ad8fe53-0443-4f16-85f8-0973491d907a","fa3b9394-705d-4912-86e9-a28a85d1806d","6005de4d-5464-4339-bbaf-99fe6edc4701","1ced7933-6529-48d2-a950-b3f585830191"]}'''

# %%
import ast

# %%
vlm_result = ast.literal_eval(vlm_result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 vlm_result = ast.literal_eval(vlm_result)
#
# File /opt/anaconda3/lib/python3.13/ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File /opt/anaconda3/lib/python3.13/ast.py:99, in literal_eval.<locals>._convert(node)
#      97     if len(node.keys) != len(node.values):
#      98         _raise_malformed_node(node)
# ---> 99     return dict(zip(map(_convert, node.keys),
#     100                     map(_convert, node.values)))
#     101 elif isinstance(node, BinOp) and isinstance(node.op, (Add, Sub)):
#     102     left = _convert_signed_num(node.left)
#
# File /opt/anaconda3/lib/python3.13/ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
# ...

# %%
import json

# %%
s = json.load(vlm_result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 s = json.load(vlm_result)
#
# File /opt/anaconda3/lib/python3.13/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# ...
